# %% [markdown]
# Hello

# %%
#Data from Kaggle dataset
# https://www.kaggle.com/datasets/sazidthe1/world-population-data
# data recorded from 1970 to 2023

# %%
# Import Dependencies
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Make a reference to the world_population.csv file path
csv_path = Path("Resources/world_population.csv")

# Import the world_population.csv file as a DataFrame
pops_df = pd.read_csv(csv_path, encoding="utf-8")

# Check if imported correctly
pops_df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
print(pops_df.count())

num_rows = pops_df.shape[0]
print("number of rows is " + str(num_rows))
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                      234
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     232
# Density (per km²)              230
# Growth Rate                    232
# World Population Percentage    234
# dtype: int64
# number of rows is 234

# %%
pops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
#set the display format for floating-point numbers, floating-point numbers will be shown with two decimal place
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
pops_df.describe()

#check which country has the lowest pop what country has 510 in 2022?
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
#check for null values/missing values
pops_df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
missing_values = pops_df[pops_df.isnull().any(axis=1)]
#print(missing_values)
missing_values

#some countries have missing population data in earlier dates.
# Out:
#      Rank CCA3              Country        Capital      Continent  \
# 13     91  AZE           Azerbaijan           Baku           Asia
# 42     28  COL             Colombia         Bogota  South America
# 59    152  GNQ    Equatorial Guinea         Malabo         Africa
# 62    159  SWZ             Eswatini        Mbabane         Africa
# 72    142  GMB               Gambia         Banjul         Africa
# 73    131  GEO              Georgia        Tbilisi           Asia
# 90     94  HUN              Hungary       Budapest         Europe
# 91    179  ISL              Iceland      Reykjavík         Europe
# 92      2  IND                India      New Delhi           Asia
# 100    52  CIV          Ivory Coast   Yamoussoukro         Africa
# 101   139  JAM              Jamaica       Kingston  North America
# 122    45  MYS             Malaysia   Kuala Lumpur           Asia
# 123   174  MDV             Maldives           Malé           Asia
# ...

# %%
#unique values
pops_df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
pops_df.sort_values(by='2020 Population', ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 149     6  NGA        Nigeria             Abuja         Africa
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
pops_df.sort_values(by='World Population Percentage', ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
print(pops_df.dtypes)
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
# Select only numeric columns
numeric_df = pops_df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Display the correlation matrix
#print(correlation_matrix)
correlation_matrix
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
#pops_df.corr()

# %%
sns.heatmap(correlation_matrix, annot = True)

plt.rcParams['figure.figsize'] = (20,10)

plt.show()
#quick check correlation

# %%
#are there any continents that having grown faster than others
#pops_df.groupby('Continent').mean()

# %%
# Select only numeric columns, have to make sure we only look at numeric values else we get errors
numeric_df = pops_df.select_dtypes(include=['float64', 'int64'])

# Add the 'Continent' column back for grouping
numeric_df['Continent'] = pops_df['Continent']

# Calculate the average of all numeric columns grouped by continent, sort values by 2022 pop
average_by_continent = numeric_df.groupby('Continent').mean().sort_values(by='2022 Population', ascending = False)

# Display the resulting DataFrame
#print(average_by_continent)
average_by_continent
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      96327387.31      94955134.37      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               89087770.00      80580835.11      48639995.33
# South America      26789395.54      25015888.69      21224743.93
# Africa             18898197.31      14598365.95      11376964.52
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# ...

# %%
#check countries in continents

pops_df[pops_df['Continent'].str.contains('Asia')].head()
# Out:
#     Rank CCA3      Country  Capital Continent  2022 Population  \
# 0     36  AFG  Afghanistan    Kabul      Asia      41128771.00
# 9    140  ARM      Armenia  Yerevan      Asia       2780469.00
# 13    91  AZE   Azerbaijan     Baku      Asia      10358074.00
# 15   154  BHR      Bahrain   Manama      Asia       1472233.00
# 16     8  BGD   Bangladesh    Dhaka      Asia     171186372.00
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.00      33753499.00      28189672.00      19542982.00
# 9        2805608.00       2878595.00       2946293.00       3168523.00
# 13              NaN       9863480.00       9237202.00       8190337.00
# 15       1477469.00       1362142.00       1213645.00        711442.00
# 16     167420951.00     157830000.00     148391139.00     129193327.00
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0       10694796.00      12486631.00      10752971.00   652230.00
# ...

# %%
# Calculate the average of all numeric columns grouped by continent, sort values by 2022 pop
df2 = numeric_df.groupby('Continent').mean().sort_values(by='2022 Population', ascending = False)


selected_columns = df2[['1970 Population', '1980 Population', '1990 Population', 
                         '2000 Population', '2010 Population', '2015 Population', 
                         '2020 Population', '2022 Population']]


# Display the resulting DataFrame
#print(average_by_continent)
selected_columns
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               43839877.83      40278333.33      48639995.33
# South America      13781939.71      17270643.29      21224743.93
# Africa              6567175.27       8586031.98      11376964.52
# Europe             13118479.82      14200004.52      14785203.94
# North America       7885865.15       9207334.03      10531660.62
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               80580835.11      89087770.00      89165003.64
# South America      25015888.69      26789395.54      29509599.71
# Africa             14598365.95      18898197.31      21419703.57
# Europe             14817685.71      14712278.68      15027454.12
# North America      12151739.60      13568016.28      14259596.25
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
pops_df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
#swap index and header
df3 = selected_columns.transpose()
df3
# Out:
# Continent              Asia  South America      Africa      Europe  \
# 1970 Population 43839877.83    13781939.71  6567175.27 13118479.82
# 1980 Population 40278333.33    17270643.29  8586031.98 14200004.52
# 1990 Population 48639995.33    21224743.93 11376964.52 14785203.94
# 2000 Population 80580835.11    25015888.69 14598365.95 14817685.71
# 2010 Population 89087770.00    26789395.54 18898197.31 14712278.68
# 2015 Population 89165003.64    29509599.71 21419703.57 15027454.12
# 2020 Population 94955134.37    30823574.50 23871435.26 14915843.92
# 2022 Population 96327387.31    31201186.29 25455879.68 15055371.82
#
# Continent        North America    Oceania
# 1970 Population     7885865.15  846968.26
# 1980 Population     9207334.03  996532.17
# 1990 Population    10531660.62 1162774.87
# 2000 Population    12151739.60 1357512.09
# 2010 Population    13568016.28 1613163.65
# 2015 Population    14259596.25 1756664.48
# 2020 Population    14855914.82 1910148.96
# ...

# %%
#average population per year/s
df3.plot()
# Out:
# <Axes: >

# %%
pops_df.boxplot()
# Out:
# <Axes: >

# %%
pops_df.select_dtypes(include = 'number')
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36      41128771.00      38972230.00      33753499.00      28189672.00
# 1     138       2842321.00       2866849.00       2882481.00       2913399.00
# 2      34      44903225.00      43451666.00      39543154.00      35856344.00
# 3     213         44273.00         46189.00         51368.00         54849.00
# 4     203         79824.00         77700.00         71746.00         71519.00
# ..    ...              ...              ...              ...              ...
# 229   226         11572.00         11655.00         12182.00         13142.00
# 230   172        575986.00        556048.00        491824.00        413296.00
# 231    46      33696614.00      32284046.00      28516545.00      24743946.00
# 232    63      20017675.00      18927715.00              NaN      13792086.00
# 233    74      16320537.00      15669666.00      14154937.00      12839771.00
#
# ...

# %%
pops_df.select_dtypes(include = 'object')
# Out:
#     CCA3            Country           Capital Continent
# 0    AFG        Afghanistan             Kabul      Asia
# 1    ALB            Albania            Tirana    Europe
# 2    DZA            Algeria           Algiers    Africa
# 3    ASM     American Samoa         Pago Pago   Oceania
# 4    AND            Andorra  Andorra la Vella    Europe
# ..   ...                ...               ...       ...
# 229  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  ESH     Western Sahara          El Aaiún    Africa
# 231  YEM              Yemen             Sanaa      Asia
# 232  ZMB             Zambia            Lusaka    Africa
# 233  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 4 columns]

# %%
world_population_df = pops_df

# %%
# Calculate growth percentage from 1970 to 2022
# Handling cases with missing data by excluding them from calculations
world_population_df['Growth 1970-2022 (%)'] = ((world_population_df['2022 Population'] - world_population_df['1970 Population']) / 
                                               world_population_df['1970 Population']) * 100

# Rank countries based on the calculated growth percentage, sorting in descending order
growth_rank_df = world_population_df[['Country', '1970 Population', '2022 Population', 'Growth 1970-2022 (%)']].dropna()
growth_rank_df = growth_rank_df.sort_values(by='Growth 1970-2022 (%)', ascending=False).reset_index(drop=True)

# Display the top 10 countries with the greatest growth
growth_rank_df.head(10)
# Out:
#                     Country  1970 Population  2022 Population  \
# 0      United Arab Emirates        298084.00       9441129.00
# 1                     Qatar        118007.00       2695122.00
# 2                   Mayotte         35383.00        326101.00
# 3  Turks and Caicos Islands          5665.00         45703.00
# 4                  Djibouti        144379.00       1120849.00
# 5            Western Sahara         76371.00        575986.00
# 6                    Jordan       1557374.00      11285869.00
# 7              Sint Maarten          6260.00         44175.00
# 8                      Oman        670693.00       4576298.00
# 9                   Bahrain        222555.00       1472233.00
#
#    Growth 1970-2022 (%)
# 0               3067.27
# 1               2183.87
# 2                821.63
# 3                706.76
# 4                676.32
# 5                654.19
# 6                624.67
# 7                605.67
# 8                582.32
# 9                561.51

# %%
# Filter for countries with a negative growth percentage from 1970 to 2022
population_decrease_df = growth_rank_df[growth_rank_df['Growth 1970-2022 (%)'] < 0]

# Display countries with an overall decrease in population
population_decrease_df.reset_index(drop=True)
# Out:
#                    Country  1970 Population  2022 Population  \
# 0                  Romania      19922618.00      19659267.00
# 1                  Estonia       1361999.00       1326062.00
# 2                  Hungary      10315366.00       9967308.00
# 3                  Croatia       4492638.00       4030358.00
# 4                  Moldova       3711140.00       3272996.00
# 5                Lithuania       3210147.00       2750055.00
# 6   Bosnia and Herzegovina       3815561.00       3233526.00
# 7                  Ukraine      47279086.00      39701739.00
# 8             Cook Islands         20470.00         17011.00
# 9                 Bulgaria       8582950.00       6781953.00
# 10                  Latvia       2397414.00       1850651.00
# 11            Vatican City           752.00           510.00
# 12              Montserrat         11402.00          4390.00
# 13                    Niue          5185.00          1934.00
#
#     Growth 1970-2022 (%)
# ...

# %%
#Check japan
japan_population_data = pops_df


japan_population_data = growth_rank_df[growth_rank_df['Country'] == 'Japan']
japan_population_data
# Out:
#     Country  1970 Population  2022 Population  Growth 1970-2022 (%)
# 196   Japan     105416839.00     123951692.00                 17.58

# %%
#Check between 2000 and 2023
# Calculate the growth percentage from 2000 to 2022
world_population_df['Growth 2000-2022 (%)'] = (
    (world_population_df['2022 Population'] - world_population_df['2000 Population']) / 
    world_population_df['2000 Population']
) * 100

# Filter for countries with a negative growth percentage from 2000 to 2022
population_decrease_2000_2022 = world_population_df[
    world_population_df['Growth 2000-2022 (%)'] < 0
]

# Display countries with an overall decrease in population from 2000 to 2022
population_decrease_2000_2022[['Country', '2000 Population', '2022 Population', 'Growth 2000-2022 (%)']]
# Out:
#                               Country  2000 Population  2022 Population  \
# 1                             Albania       3182021.00       2842321.00
# 3                      American Samoa         58230.00         44273.00
# 9                             Armenia       3168523.00       2780469.00
# 18                            Belarus      10256483.00       9534954.00
# 25             Bosnia and Herzegovina       4179350.00       3233526.00
# 30                           Bulgaria       8097691.00       6781953.00
# 46                            Croatia       4548434.00       4030358.00
# 61                            Estonia       1396877.00       1326062.00
# 77                             Greece      11038109.00      10384971.00
# 80                         Guadeloupe        424067.00        395752.00
# 90                            Hungary      10202055.00       9967308.00
# 102                             Japan     126803861.00     123951692.00
# ...

# %%
#graph testing
# Bar chart for percentage decline comparison
countries_decline = population_decrease_df[['Country', 'Growth 1970-2022 (%)']]
countries_decline.set_index('Country').plot(kind='bar', color='tomato', legend=False)
plt.title("Population Decline Percentage by Country (1970 - 2022)")
plt.xlabel("Country")
plt.ylabel("Population Decline (%)")
plt.show()

# %%
# Filter for countries with population decline
countries_decline = ['Ukraine', 'Latvia', 'Lithuania', 'Bulgaria']  # Example countries with decline
decline_data = world_population_df[world_population_df['Country'].isin(countries_decline)]

# Plot population over years for each country
years = ['1970 Population', '1980 Population', '1990 Population', '2000 Population', '2010 Population', '2022 Population']
for country in countries_decline:
    plt.plot(years, decline_data[decline_data['Country'] == country][years].values.flatten(), label=country)

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Decline Over Time for Selected Countries')
plt.legend()
plt.show()

# %%
decline_percentages = population_decrease_2000_2022[['Country', 'Growth 2000-2022 (%)']]

# Plot a bar chart
decline_percentages.plot(kind='bar', x='Country', y='Growth 2000-2022 (%)', color='salmon')
plt.title('Percentage Population Decline (2000-2022)')
plt.xlabel('Country')
plt.ylabel('Population Decline (%)')
plt.xticks(rotation=45)
plt.show()
